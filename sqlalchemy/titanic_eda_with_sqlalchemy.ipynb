# %% [markdown]
# # EDA with sqlalchemy
#
# ## Get dataset from [Titanic extended dataset (Kaggle + Wikipedia)](https://www.kaggle.com/pavlofesenko/titanic-extended)
#
# ## References
# - [SQLAlchemy ORM Tutorial for Python Developers](https://auth0.com/blog/sqlalchemy-orm-tutorial-for-python-developers/?utm_source=medium&utm_medium=sc&utm_campaign=sqlalchemy_python)
# - [SQL로 맛보는 데이터 전처리 분석](http://www.yes24.com/Product/Goods/86544423)

# %% [markdown]
# # Load packages

# %%
# %load_ext lab_black

# %%
import pandas as pd
import sqlalchemy as db
import pymysql
from _secrets import PASSWORD
from pathlib import Path

# %% [markdown]
# # Connect MySQL DB

# %%
IP = "localhost"
DB_NAME = "testdb"
TABLE_NAME = "titanic"
USER = "root"
db_url = f"mysql+pymysql://{USER}:{PASSWORD}@{IP}/{DB_NAME}"
engine = db.create_engine(db_url)
connection = engine.connect()
print(engine.table_names())
# Out:
# ['test_table', 'titanic', 'user']
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:8: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)

# %% [markdown]
# # Inject data

# %%
filepath = Path("archive/full.csv")
df = pd.read_csv(filepath)

# %%
# To resovle unicode error. For details, check the link below
# https://stackoverflow.com/questions/65012603/removing-rows-contains-non-english-words-in-pandas-dataframe
def is_ascii(s):
    try:
        s.encode(encoding="utf-8").decode("ascii")
    except UnicodeDecodeError:
        return False
    except:
        return True
    else:
        return True

target_columns = ["Name", "Name_wiki", "Hometown", "Boarded", "Destination"]

for column in target_columns:
    df = df[df[column].map(lambda x: is_ascii(x))]
# Out:
# Name
# Name_wiki
# Hometown
# Boarded
# Destination

# %%
# Drop if table already exists
query = f"DROP TABLE IF EXISTS {TABLE_NAME}"
engine.execute(query)

# IF not, inject
df.to_sql(TABLE_NAME, con=engine, index=True)

# %% [markdown]
# # 요인별 생존 여부 관계

# %%
metadata = db.MetaData()
titanic = db.Table("titanic", metadata, autoload=True, autoload_with=engine)
columns = [x.replace("titanic.", "") for x in titanic.columns.keys()]

# %%
def execute_query(query: str) -> pd.DataFrame:
    result_proxy = connection.execute(query)
    result_set = result_proxy.fetchall()
    result_df = pd.DataFrame(
        result_set,
        columns=columns,
    ).set_index("index")
    return result_df

# %% [markdown]
# ## 성별

# %%
query = "SELECT * FROM titanic LIMIT 10;"
execute_query(query)
# Out:
#        PassengerId  Survived  Pclass                            Name     Sex  \
# index
# 0                1       0.0       3         Braund, Mr. Owen Harris    male
# 4                5       0.0       3        Allen, Mr. William Henry    male
# 5                6       0.0       3                Moran, Mr. James    male
# 6                7       0.0       1         McCarthy, Mr. Timothy J    male
# 11              12       1.0       1        Bonnell, Miss. Elizabeth  female
# 12              13       0.0       3  Saundercock, Mr. William Henry    male
# 16              17       0.0       3            Rice, Master. Eugene    male
# 17              18       1.0       2    Williams, Mr. Charles Eugene    male
# 19              20       1.0       3         Masselmani, Mrs. Fatima  female
# 20              21       0.0       2            Fynney, Mr. Joseph J    male
#
#         Age  SibSp  Parch     Ticket     Fare  ... Embarked  WikiId  \
# index                                          ...
# 0      22.0      1      0  A/5 21171   7.2500  ...        S   691.0
# 4      35.0      0      0     373450   8.0500  ...        S   627.0
# 5       NaN      0      0     330877   8.4583  ...        Q   785.0
# 6      54.0      0      0      17463  51.8625  ...        S   200.0
# 11     58.0      0      0     113783  26.5500  ...        S    35.0
# 12     20.0      0      0  A/5. 2151   8.0500  ...        S  1196.0
# 16      2.0      4      1     382652  29.1250  ...        Q  1151.0
# 17      NaN      0      0     244373  13.0000  ...        S   604.0
# 19      NaN      0      0       2649   7.2250  ...        C  1053.0
# 20     35.0      0      0     239865  26.0000  ...        S   416.0
#
#                                            Name_wiki Age_wiki  \
# index
# 0                            Braund, Mr. Owen Harris     22.0
# 4                           Allen, Mr. William Henry     35.0
# 5      Doherty, Mr. William John (aka "James Moran")     22.0
# 6                           McCarthy, Mr. Timothy J.     54.0
# 11                           Bonnell, Miss Elizabeth     61.0
# 12                    Saundercock, Mr. William Henry     19.0
# 16                       Rice, Master Eugene Francis      2.0
# 17                      Williams, Mr. Charles Eugene     23.0
# 19                           Muslamani, Mrs. Fatimah     22.0
# 20                             Fynney, Mr. Joseph J.     35.0
#
#                                  Hometown      Boarded  \
# index
# 0              Bridgerule, Devon, England  Southampton
# 4      Birmingham, West Midlands, England  Southampton
# 5                           Cork, Ireland   Queenstown
# 6           Dorchester, Massachusetts, US  Southampton
# 11                   Youngstown, Ohio, US  Southampton
# 12          St Austell, Cornwall, England  Southampton
# 16            Athlone, Westmeath, Ireland   Queenstown
# 17                Harrow, London, England  Southampton
# 19                       Tebnine, Lebanon    Cherbourg
# 20     Liverpool, Merseyside, England, UK  Southampton
#
#                                    Destination Lifeboat   Body Class
# index
# 0      Qu'Appelle Valley, Saskatchewan, Canada     None   None   3.0
# 4                                New York City     None   None   3.0
# 5                                New York City     None   None   3.0
# 6                Dorchester, Massachusetts, US     None  175MB   1.0
# 11                        Youngstown, Ohio, US        8   None   1.0
# 12                               New York City     None   None   3.0
# 16                     Spokane, Washington, US     None   None   3.0
# 17                       Chicago, Illinois, US       14   None   2.0
# 19                  Michigan City, Indiana, US        C   None   3.0
# 20                    Montreal, Quebec, Canada     None   322M   2.0
#
# [10 rows x 21 columns]

# %%
# query = "SELECT COUNT(PASSENGERID) N_PASSENGGERS, COUNT(DISTINCT PASSENGERID) N_D_PASSENGERS FROM titanic;"
query = db.select(
    [
        db.func.count(titanic.columns.PassengerId).label("N_PASSENGERS"),
        db.func.count(titanic.columns.PassengerId.distinct()).label("N_D_PASSENGERS"),
    ]
)
result_proxy = connection.execute(query)
result_set = result_proxy.fetchall()
pd.DataFrame(result_set, columns=["N_PASSENGERS", "N_D_PASSENGERS"])
# Out:
#    N_PASSENGERS  N_D_PASSENGERS
# 0           911             911
